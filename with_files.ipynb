# %%
def read_hole_file(name_file):
    f = open(name_file, 'r')
    f_r = f.read()
    return f_r

# %%
grades_file = read_hole_file('grades.csv').split('\n')

# %%
grades_file_lst = []
for file in grades_file:
    file = file.split(';')
    grades_file_lst.append(file)

# %%
grades_file_lst
# Out:
# [['AAliutova_2_2', '70', '7(8)'],
#  ['AAliutova_13_1', '75', '8'],
#  ['AAliutova_13_2', '75', '9, 10'],
#  ['AAliutova_26_2', '70', '7(8)'],
#  ['AAliutova_27_1', '70', '7(8)'],
#  ['AAliutova_27_2', '70', '6, 7'],
#  ['AAliutova_30_1', '70', '6'],
#  ['VKovalevskaya_2_2', '70', '7, 8'],
#  ['VKovalevskaya_3_2', '70', '7'],
#  ['VKovalevskaya_5_2', '80', '8, 9'],
#  ['VKovalevskaya_9_2', '70', '7, 8'],
#  ['VKovalevskaya_12_2', '70', '8(7)'],
#  ['VKovalevskaya_21_2', '70', '7'],
#  ['VKovalevskaya_24_2', '70', '9(8)'],
#  ['VKovalevskaya_29_2', '70', '7, 8'],
#  ['VKovalevskaya_34_2', '70', '10'],
#  ['ZEvdaeva_3_1', '70', '7, 8'],
#  ['ZEvdaeva_3_2', '70', '7(8)'],
#  ['EEmelyanova_14_1', '70', '8, 9'],
#  ['EEmelyanova_14_2', '70', '8'],
#  ['EEmelyanova_16_1', '70', '7, 8'],
#  ['EEmelyanova_16_2', '70', '7(8)'],
#  ['MTsygunova_6_2', '70', '7'],
#  ['KKolosova_9_1', '70', '7'],
#  ['KKolosova_9_2', '70', '8(7)'],
#  ['KKolosova_24_1', '70', '7, 8'],
# ...

# %%
trans = read_hole_file('new_filenames.csv')

# %%
trans
# Out:
# '\ufeffDegtyar_1_2.ann;ADe_1_2.ann\nINaumov_51_1.ann;INa_51_1.ann\nPolyanskaya_19_2.ann;LPo_19_2.ann\nAStepanova_33_2.ann;ASt_33_2.ann\nZakharova_95_1.ann;EZa_95_1.ann\nDArsentyev_32_2.ann;DAr_32_2.ann\nVKovalevskaya_30_1.txt;VKo_30_1.txt\nKKolosova_12_2.ann;KKo_12_2.ann\nZakharova_2_2.txt;EZa_2_2.txt\nZakharova_17_1.txt;EZa_17_1.txt\nMelnik_24_1.ann;AMe_24_1.ann\nShatova_1_2.ann;ESha_1_2.ann\nAAliutova_3_2.txt;AAl_3_2.txt\nShatova_24_1.ann;ESha_24_1.ann\nVKovalevskaya_19_2.ann;VKo_19_2.ann\nPechnikova_7_1.txt;VPe_7_1.txt\nKhromalenkova_34_1.txt;AKhr_34_1.txt\nStukanov_9_1.ann;ASt_9_1.ann\nEEmelyanova_15_1.ann;EEm_15_1.ann\nShatova_64_2.txt;ESha_64_2.txt\nKhromalenkova_3_2.ann;AKhr_3_2.ann\nShatova_69_2.txt;ESha_69_2.txt\nLPasalskaya_75_2.txt;EPa_75_2.txt\nGromov_12_2.txt;MGr_12_2.txt\nShatova_10_2.ann;ESha_10_2.ann\nMTsygunova_24_1.ann;MTsy_24_1.ann\nKKolosova_12_2.txt;KKo_12_2.txt\nPasalskaya_25_1.txt;EPa_25_1.txt\nMelnik_6_2.txt;AMe_6_2.txt\nAStepanova_40_2.ann;ASt_40_2.ann\nVinog
# ...

# %%
for x in trans_new:
    if '14_2' in x[1]:
        print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ce027d239957> in <module>()
# ----> 1 for x in trans_new:
#       2     if '14_2' in x[1]:
#       3         print(x)
#
# NameError: name 'trans_new' is not defined

# %%
trans_mass = trans.split('\n')
trans_new = []
for every_trans in trans_mass:
    if 'txt' in every_trans:
        two = every_trans.split(';')
        trans_new.append(two)

# %%
for esse in grades_file_lst:
    txt = esse[0] + '.txt'
    esse[0] = txt
    for trans_file in trans_new:
        if txt == trans_file[0]:
            esse.append(trans_file[1] + '\n')

# %%
grades_file_lst
# Out:
# [['AAliutova_2_2.txt', '70', '7(8)', 'AAl_2_2.txt\n'],
#  ['AAliutova_13_1.txt', '75', '8', 'AAl_13_1.txt\n'],
#  ['AAliutova_13_2.txt', '75', '9, 10', 'AAl_13_2.txt\n'],
#  ['AAliutova_26_2.txt', '70', '7(8)', 'AAl_26_2.txt\n'],
#  ['AAliutova_27_1.txt', '70', '7(8)', 'AAl_27_1.txt\n'],
#  ['AAliutova_27_2.txt', '70', '6, 7', 'AAl_27_2.txt\n'],
#  ['AAliutova_30_1.txt', '70', '6', 'AAl_30_1.txt\n'],
#  ['VKovalevskaya_2_2.txt', '70', '7, 8', 'VKo_2_2.txt\n'],
#  ['VKovalevskaya_3_2.txt', '70', '7', 'VKo_3_2.txt\n'],
#  ['VKovalevskaya_5_2.txt', '80', '8, 9', 'VKo_5_2.txt\n'],
#  ['VKovalevskaya_9_2.txt', '70', '7, 8', 'VKo_9_2.txt\n'],
#  ['VKovalevskaya_12_2.txt', '70', '8(7)', 'VKo_12_2.txt\n'],
#  ['VKovalevskaya_21_2.txt', '70', '7', 'VKo_21_2.txt\n'],
#  ['VKovalevskaya_24_2.txt', '70', '9(8)', 'VKo_24_2.txt\n'],
#  ['VKovalevskaya_29_2.txt', '70', '7, 8', 'VKo_29_2.txt\n'],
#  ['VKovalevskaya_34_2.txt', '70', '10', 'VKo_34_2.txt\n'],
# ...

# %%
for f in grades_file_lst:
    f[0] = f[0] + ';'
    f[1] = f[1] + ';'
    f[2] = f[2] + ';'

# %%
oi = read_hole_file('gradesOI.csv').split('\n')

# %%
one_more = []
for one_oi in oi:
    one_more.append(one_oi.split(';'))

# %%
one_more
# Out:
# [['10_1', 'aver'],
#  ['10_2', 'aver'],
#  ['11_1', 'good-lower'],
#  ['11_2', 'good-lower'],
#  ['12_1', 'good'],
#  ['12_2', 'good-lower'],
#  ['13_1', 'good'],
#  ['13_2', 'good'],
#  ['14_1', 'aver-lower'],
#  ['14_2', 'aver-lower'],
#  ['15_1', 'aver'],
#  ['15_2', 'aver'],
#  ['16_1', 'aver'],
#  ['16_2', 'aver'],
#  ['17_1', 'unsatisf'],
#  ['17_2', 'aver'],
#  ['18_1', 'good-lower'],
#  ['18_2', 'good-lower'],
#  ['19_1', 'aver-lower'],
#  ['19_2', 'aver-lower'],
#  ['1_1', 'aver'],
#  ['1_2', 'good-lower'],
#  ['20_1', 'aver'],
#  ['20_2', 'aver-lower'],
#  ['21_1', 'aver-lower'],
#  ['21_2', 'aver-lower'],
#  ['22_1', 'aver-lower'],
#  ['22_2', 'aver'],
#  ['23_1', 'aver'],
#  ['23_2', 'aver-lower'],
#  ['24_1', 'aver-lower'],
#  ['24_2', 'aver'],
#  ['25_1', 'aver'],
#  ['25_2', 'aver'],
#  ['26_1', 'aver'],
#  ['26_2', 'aver-lower'],
#  ['27_1', 'aver-lower'],
#  ['27_2', 'aver-lower'],
#  ['28_1', 'good-lower'],
#  ['28_2', 'good'],
#  ['29_1', 'aver'],
# ...

# %%
for o in one_more:
    o[0] = o[0] + '.txt;'
    o[1] = o[1] + '\n'

# %%
one_more
# Out:
# [['10_1.txt;', 'aver\n'],
#  ['10_2.txt;', 'aver\n'],
#  ['11_1.txt;', 'good-lower\n'],
#  ['11_2.txt;', 'good-lower\n'],
#  ['12_1.txt;', 'good\n'],
#  ['12_2.txt;', 'good-lower\n'],
#  ['13_1.txt;', 'good\n'],
#  ['13_2.txt;', 'good\n'],
#  ['14_1.txt;', 'aver-lower\n'],
#  ['14_2.txt;', 'aver-lower\n'],
#  ['15_1.txt;', 'aver\n'],
#  ['15_2.txt;', 'aver\n'],
#  ['16_1.txt;', 'aver\n'],
#  ['16_2.txt;', 'aver\n'],
#  ['17_1.txt;', 'unsatisf\n'],
#  ['17_2.txt;', 'aver\n'],
#  ['18_1.txt;', 'good-lower\n'],
#  ['18_2.txt;', 'good-lower\n'],
#  ['19_1.txt;', 'aver-lower\n'],
#  ['19_2.txt;', 'aver-lower\n'],
#  ['1_1.txt;', 'aver\n'],
#  ['1_2.txt;', 'good-lower\n'],
#  ['20_1.txt;', 'aver\n'],
#  ['20_2.txt;', 'aver-lower\n'],
#  ['21_1.txt;', 'aver-lower\n'],
#  ['21_2.txt;', 'aver-lower\n'],
#  ['22_1.txt;', 'aver-lower\n'],
#  ['22_2.txt;', 'aver\n'],
#  ['23_1.txt;', 'aver\n'],
#  ['23_2.txt;', 'aver-lower\n'],
#  ['24_1.txt;', 'aver-lower\n'],
#  ['24_2.txt;', 'aver\n'],
# ...

# %%
grades_file_lst
one_more
# Out:
# [['10_1.txt;', 'aver\n'],
#  ['10_2.txt;', 'aver\n'],
#  ['11_1.txt;', 'good-lower\n'],
#  ['11_2.txt;', 'good-lower\n'],
#  ['12_1.txt;', 'good\n'],
#  ['12_2.txt;', 'good-lower\n'],
#  ['13_1.txt;', 'good\n'],
#  ['13_2.txt;', 'good\n'],
#  ['14_1.txt;', 'aver-lower\n'],
#  ['14_2.txt;', 'aver-lower\n'],
#  ['15_1.txt;', 'aver\n'],
#  ['15_2.txt;', 'aver\n'],
#  ['16_1.txt;', 'aver\n'],
#  ['16_2.txt;', 'aver\n'],
#  ['17_1.txt;', 'unsatisf\n'],
#  ['17_2.txt;', 'aver\n'],
#  ['18_1.txt;', 'good-lower\n'],
#  ['18_2.txt;', 'good-lower\n'],
#  ['19_1.txt;', 'aver-lower\n'],
#  ['19_2.txt;', 'aver-lower\n'],
#  ['1_1.txt;', 'aver\n'],
#  ['1_2.txt;', 'good-lower\n'],
#  ['20_1.txt;', 'aver\n'],
#  ['20_2.txt;', 'aver-lower\n'],
#  ['21_1.txt;', 'aver-lower\n'],
#  ['21_2.txt;', 'aver-lower\n'],
#  ['22_1.txt;', 'aver-lower\n'],
#  ['22_2.txt;', 'aver\n'],
#  ['23_1.txt;', 'aver\n'],
#  ['23_2.txt;', 'aver-lower\n'],
#  ['24_1.txt;', 'aver-lower\n'],
#  ['24_2.txt;', 'aver\n'],
# ...

# %%
string = ''
for every in grades_file_lst:
    for each in every:
        string = string + each
for every1 in one_more:
    for each1 in every1:
        string = string + each1

# %%
string
# Out:
# 'AAliutova_2_2.txt;70;7(8);AAl_2_2.txt\nAAliutova_13_1.txt;75;8;AAl_13_1.txt\nAAliutova_13_2.txt;75;9, 10;AAl_13_2.txt\nAAliutova_26_2.txt;70;7(8);AAl_26_2.txt\nAAliutova_27_1.txt;70;7(8);AAl_27_1.txt\nAAliutova_27_2.txt;70;6, 7;AAl_27_2.txt\nAAliutova_30_1.txt;70;6;AAl_30_1.txt\nVKovalevskaya_2_2.txt;70;7, 8;VKo_2_2.txt\nVKovalevskaya_3_2.txt;70;7;VKo_3_2.txt\nVKovalevskaya_5_2.txt;80;8, 9;VKo_5_2.txt\nVKovalevskaya_9_2.txt;70;7, 8;VKo_9_2.txt\nVKovalevskaya_12_2.txt;70;8(7);VKo_12_2.txt\nVKovalevskaya_21_2.txt;70;7;VKo_21_2.txt\nVKovalevskaya_24_2.txt;70;9(8);VKo_24_2.txt\nVKovalevskaya_29_2.txt;70;7, 8;VKo_29_2.txt\nVKovalevskaya_34_2.txt;70;10;VKo_34_2.txt\nZEvdaeva_3_1.txt;70;7, 8;ZEv_3_1.txt\nZEvdaeva_3_2.txt;70;7(8);ZEv_3_2.txt\nEEmelyanova_14_1.txt;70;8, 9;EEm_14_1.txt\nEEmelyanova_14_2.txt;70;8;EEm_14_2.txt\nEEmelyanova_16_1.txt;70;7, 8;EEm_16_1.txt\nEEmelyanova_16_2.txt;70;7(8);EEm_16_2.txt\nMTsygunova_6_2.txt;70;7;MTsy_6_2.txt\nKKolosova_9_1.txt;70;7;KKo_9_1.txt\nKKolosova
# ...

# %%
f = open('grades_all.csv', 'w')
f.write(string)
f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d0978a54ee5a> in <module>()
#       1 f = open('grades_all.csv', 'w')
# ----> 2 f.write(string)
#       3 f.close()
#
# NameError: name 'string' is not defined

# %%
n = read_hole_file('itog.csv').split('\n')

# %%
n
# Out:
# ['AAl_13_1;best',
#  'AAl_27_1;best',
#  'AAl_30_1;best',
#  'ZEv_3_1;best',
#  'EEm_14_1;best',
#  'EEm_16_1;best',
#  'KKo_9_1;best',
#  'KKo_24_1;best',
#  'ASt_21_1;best',
#  'ASt_34_1;best',
#  '12_1;best',
#  '13_1;best',
#  'AAl_2_2;best',
#  'AAl_13_2;best',
#  'AAl_26_2;best',
#  'AAl_27_2;best',
#  'VKo_2_2;best',
#  'VKo_3_2;best',
#  'VKo_5_2;best',
#  'VKo_9_2;best',
#  'VKo_12_2;best',
#  'VKo_21_2;best',
#  'VKo_24_2;best',
#  'VKo_29_2;best',
#  'VKo_34_2;best',
#  'ZEv_3_2;best',
#  'EEm_14_2;best',
#  'EEm_16_2;best',
#  'MTsy_6_2;best',
#  'KKo_9_2;best',
#  'KKo_24_2;best',
#  'LPo_16_2;best',
#  'ASt_2_2;best',
#  'ASt_21_2;best',
#  'ASt_34_2;best',
#  '13_2;best',
#  '28_2;best',
#  '2_2;best',
#  '10_1;aver',
#  '11_1;aver',
#  '14_1;aver',
#  '15_1;aver',
#  '16_1;aver',
#  '18_1;aver',
#  '19_1;aver',
#  '1_1;aver',
#  '20_1;aver',
#  '21_1;aver',
#  '22_1;aver',
#  '23_1;aver',
#  '24_1;aver',
#  '25_1;aver',
#  '26_1;aver',
#  '27_1;aver',
#  '28_1;aver',
# ...

# %%
file_grade = []
for nn in n:
    nn = nn.split(';')
    file_grade.append(['/Users/irene/Desktop/Курсовая/esseys/' + nn[0], nn[1]])

# %%
len(file_grade)
# Out:
# 96

# %%
file_grade
# Out:
# [['/Users/irene/Desktop/Курсовая/esseys/AAl_13_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_27_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_30_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/ZEv_3_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/EEm_14_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/EEm_16_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/KKo_9_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/KKo_24_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/ASt_21_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/ASt_34_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/12_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/13_1', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_2_2', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_13_2', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_26_2', 'best'],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_27_2', 'best'],
# ...

# %%
from te import count_tokens, get_parsed_text

# %%
for every in file_grade:
    parsed_text = get_parsed_text('english-partut-ud-2.0-170801.udpipe', every[0]+'.txt')
    num_tok = count_tokens(parsed_text)
    every.append(num_tok)

# %%
file_grade
# Out:
# [['/Users/irene/Desktop/Курсовая/esseys/AAl_13_1', 'best', 282],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_27_1', 'best', 211],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_30_1', 'best', 232],
#  ['/Users/irene/Desktop/Курсовая/esseys/ZEv_3_1', 'best', 201],
#  ['/Users/irene/Desktop/Курсовая/esseys/EEm_14_1', 'best', 219],
#  ['/Users/irene/Desktop/Курсовая/esseys/EEm_16_1', 'best', 198],
#  ['/Users/irene/Desktop/Курсовая/esseys/KKo_9_1', 'best', 221],
#  ['/Users/irene/Desktop/Курсовая/esseys/KKo_24_1', 'best', 213],
#  ['/Users/irene/Desktop/Курсовая/esseys/ASt_21_1', 'best', 203],
#  ['/Users/irene/Desktop/Курсовая/esseys/ASt_34_1', 'best', 175],
#  ['/Users/irene/Desktop/Курсовая/esseys/12_1', 'best', 193],
#  ['/Users/irene/Desktop/Курсовая/esseys/13_1', 'best', 203],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_2_2', 'best', 335],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_13_2', 'best', 317],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_26_2', 'best', 384],
# ...

# %%
words = []
for h in file_grade:
    words.append(h[2])

# %%
d = {}
i = 0
for w in words:
    if w not in d:
        d[w] = [i]
    else:
        d[w].append(i)
    i += 1

# %%
for dd in d:
    if len(d[dd]) != 1:
        print(d[dd])
# Out:
# [2, 61]
# [8, 11]
# [10, 89]
# [12, 67]
# [16, 30]
# [17, 76]
# [18, 27]
# [19, 34]
# [21, 48]
# [28, 33]
# [29, 36]
# [35, 68]
# [38, 40]
# [39, 55, 84]
# [49, 83]
# [57, 62, 73]
# [80, 86]
# [85, 88]

# %%
import re

# %%
file_grade[0]
# Out:
# ['/Users/irene/Desktop/Курсовая/esseys/AAl_13_1', 'best', 282]

# %%
for n in file_grade:
    num = re.search('([0-9])$', n[0]).group(1)
    n.append(num)

# %%
file_grade
# Out:
# [['/Users/irene/Desktop/Курсовая/esseys/AAl_13_1', 'best', 282, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_27_1', 'best', 211, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_30_1', 'best', 232, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/ZEv_3_1', 'best', 201, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/EEm_14_1', 'best', 219, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/EEm_16_1', 'best', 198, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/KKo_9_1', 'best', 221, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/KKo_24_1', 'best', 213, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/ASt_21_1', 'best', 203, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/ASt_34_1', 'best', 175, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/12_1', 'best', 193, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/13_1', 'best', 203, '1'],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_2_2', 'best', 335, '2'],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_13_2', 'best', 317, '2'],
# ...

# %%
string = ''

# %%
for file in file_grade:
    if file[1] == 'best' and file[3] == '1':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + file[3] + '\n'

# %%
string
# Out:
# 'AAl_13_1\tbest\t282\t1\nAAl_27_1\tbest\t211\t1\nAAl_30_1\tbest\t232\t1\nZEv_3_1\tbest\t201\t1\nEEm_14_1\tbest\t219\t1\nEEm_16_1\tbest\t198\t1\nKKo_9_1\tbest\t221\t1\nKKo_24_1\tbest\t213\t1\nASt_21_1\tbest\t203\t1\nASt_34_1\tbest\t175\t1\n12_1\tbest\t193\t1\n13_1\tbest\t203\t1\n'

# %%
for file in file_grade:
    if file[1] == 'best' and file[3] == '2':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + file[3] + '\n'

# %%
for file in file_grade:
    if file[1] == 'aver' and file[3] == '1':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + file[3] + '\n'

# %%
for file in file_grade:
    if file[1] == 'aver' and file[3] == '2':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + file[3] + '\n'

# %%
for file in file_grade:
    if file[1] == 'worst' and file[3] == '1':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + file[3] + '\n'

# %%
for file in file_grade:
    if file[1] == 'worst' and file[3] == '2':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + file[3] + '\n'

# %%
f = open('result.tsv', 'w')
f.write(string)
f.close()

# %%
from te import av_depth_for_one_text, max_depth_for_one_text, min_depth_for_one_text, get_parsed_text

# %%
n = read_hole_file('grades_all.csv').split('\n')

# %%
file_grade = []
for nn in n:
    nn = nn.split(';')
    file_grade.append(['/Users/irene/Desktop/Курсовая/esseys/' + nn[0], nn[3]])

# %%
for every in file_grade:
    parsed_text = get_parsed_text('english-partut-ud-2.0-170801.udpipe', every[0]+'.txt')
    #print(every[0])
    av = round(av_depth_for_one_text(parsed_text), 4)
    ma = max_depth_for_one_text(parsed_text)
    mi = min_depth_for_one_text(parsed_text)
    every.append(av)
    every.append(ma)
    every.append(mi)

# %%
file_grade[0]
# Out:
# ['/Users/irene/Desktop/Курсовая/esseys/AAl_13_1',
#  'best',
#  282,
#  '1',
#  4.2727,
#  8,
#  2]

# %%
for n in file_grade:
    n.append(re.search('([0-9])\.', n[0]).group(1))

# %%
string = ''

# %%
for file in file_grade:
    if file[1] == 'best' and file[5] == '1':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\n'

# %%
for file in file_grade:
    if file[1] == 'best' and file[5] == '2':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\n'

# %%
for file in file_grade:
    if file[1] == 'aver' and file[5] == '1':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\n'

# %%
for file in file_grade:
    if file[1] == 'aver' and file[5] == '2':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\n'

# %%
for file in file_grade:
    if file[1] == 'worst' and file[5] == '1':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\n'

# %%
for file in file_grade:
    if file[1] == 'worst' and file[5] == '2':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\n'

# %%
f = open('res2.tsv', 'w')
f.write(string)
f.close()

# %%
from te import count_dependent_sent_text, count_sent

# %%
n = read_hole_file('grades_all.csv').split('\n')

# %%
file_grade = []
for nn in n:
    nn = nn.split(';')
    file_grade.append(['/Users/irene/Desktop/Курсовая/esseys/' + nn[0], nn[3]])

# %%
for every in file_grade:
    parsed_text = get_parsed_text('english-partut-ud-2.0-170801.udpipe', every[0]+'.txt')
    acl, rel_cl, advcl = count_dependent_sent_text(parsed_text)
    s = count_sent(parsed_text)
    every.append(acl)
    every.append(rel_cl)
    every.append(advcl)
    every.append(s)

# %%
for n in file_grade:
    n.append(re.search('([0-9])\.', n[0]).group(1))

# %%
string = ''

# %%
for k in file_grade:
    string = string + str(k[0]) + '\t' + str(k[1]) + '\t' + str(k[3]) + '\t' + str(k[2]) + '\t' + str(k[4]) + '\t' + str(k[5]) + '\t' + str(k[6]) + '\t' + str(k[7]) + '\t' + str(k[8]) + '\t' + str(k[9]) + '\t' + str(k[10]) + '\n'

# %%
f = open('resss.tsv', 'w')
f.write(string)
f.close()

# %%
file_grade[0]
# Out:
# ['/Users/irene/Desktop/Курсовая/esseys/AAl_13_1',
#  'best',
#  282,
#  '1',
#  4.2727,
#  8,
#  2,
#  6,
#  1,
#  3,
#  11]

# %%
string = ''

# %%
for file in file_grade:
    if file[1] == 'best' and file[6] == '1':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\t' + str(file[5]) + '\t' + file[6] +'\n'

# %%
for file in file_grade:
    if file[1] == 'best' and file[6] == '2':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\t' + str(file[5]) + '\t' + file[6] + '\n'

# %%
for file in file_grade:
    if file[1] == 'aver' and file[6] == '1':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\t' + str(file[5]) + '\t' + file[6] + '\n'

# %%
for file in file_grade:
    if file[1] == 'aver' and file[6] == '2':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\t' + str(file[5]) + '\t' + file[6] + '\n'

# %%
for file in file_grade:
    if file[1] == 'worst' and file[6] == '1':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\t' + str(file[5]) + '\t' + file[6] + '\n'

# %%
for file in file_grade:
    if file[1] == 'worst' and file[6] == '2':
        name = re.search(r'(.+?/){5}(.+?).txt', file[0]).group(2)
        string = string + name + '\t' + file[1] + '\t' + str(file[2]) + '\t' + str(file[3]) + '\t' + str(file[4]) + '\t' + str(file[5]) + '\t' + file[6] + '\n'

# %%
f = open('res3.tsv', 'w')
f.write(string)
f.close()

# %%
string
# Out:
# '/Users/irene/Desktop/Курсовая/esseys/AAl_13_1\tbest\t1\t282\t4.2727\t8\t2\t6\t1\t3\t11\n/Users/irene/Desktop/Курсовая/esseys/AAl_27_1\tbest\t1\t211\t5.0\t10\t3\t0\t0\t1\t10\n/Users/irene/Desktop/Курсовая/esseys/AAl_30_1\tbest\t1\t232\t3.7143\t5\t2\t2\t1\t1\t14\n/Users/irene/Desktop/Курсовая/esseys/ZEv_3_1\tbest\t1\t201\t4.75\t7\t3\t4\t3\t2\t8\n/Users/irene/Desktop/Курсовая/esseys/EEm_14_1\tbest\t1\t219\t5.4444\t7\t4\t4\t0\t6\t9\n/Users/irene/Desktop/Курсовая/esseys/EEm_16_1\tbest\t1\t198\t4.0\t6\t3\t2\t0\t2\t11\n/Users/irene/Desktop/Курсовая/esseys/KKo_9_1\tbest\t1\t221\t4.4\t6\t2\t3\t1\t6\t10\n/Users/irene/Desktop/Курсовая/esseys/KKo_24_1\tbest\t1\t213\t5.5714\t8\t3\t7\t0\t3\t7\n/Users/irene/Desktop/Курсовая/esseys/ASt_21_1\tbest\t1\t203\t4.875\t8\t4\t0\t2\t2\t8\n/Users/irene/Desktop/Курсовая/esseys/ASt_34_1\tbest\t1\t175\t4.0\t7\t2\t2\t0\t4\t9\n/Users/irene/Desktop/Курсовая/esseys/12_1\tbest\t1\t193\t4.375\t6\t3\t2\t0\t4\t8\n/Users/irene/Desktop/Курсовая/esseys/13_1\tbest\t1\t203\
# ...

# %%
file_grade
# Out:
# [['/Users/irene/Desktop/Курсовая/esseys/AAl_13_1',
#   'best',
#   282,
#   '1',
#   4.2727,
#   8,
#   2,
#   6,
#   1,
#   3,
#   11],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_27_1',
#   'best',
#   211,
#   '1',
#   5.0,
#   10,
#   3,
#   0,
#   0,
#   1,
#   10],
#  ['/Users/irene/Desktop/Курсовая/esseys/AAl_30_1',
#   'best',
#   232,
#   '1',
#   3.7143,
#   5,
#   2,
#   2,
#   1,
#   1,
#   14],
#  ['/Users/irene/Desktop/Курсовая/esseys/ZEv_3_1',
#   'best',
#   201,
#   '1',
#   4.75,
#   7,
#   3,
#   4,
#   3,
#   2,
#   8],
#  ['/Users/irene/Desktop/Курсовая/esseys/EEm_14_1',
#   'best',
#   219,
#   '1',
#   5.4444,
#   7,
#   4,
#   4,
#   0,
#   6,
#   9],
#  ['/Users/irene/Desktop/Курсовая/esseys/EEm_16_1',
#   'best',
#   198,
#   '1',
#   4.0,
#   6,
#   3,
#   2,
#   0,
#   2,
#   11],
#  ['/Users/irene/Desktop/Курсовая/esseys/KKo_9_1',
#   'best',
#   221,
#   '1',
#   4.4,
#   6,
#   2,
#   3,
#   1,
#   6,
#   10],
# ...

# %%
from kkk import count, find_possesive

# %%
for file in file_grade:
    parsed_text = get_parsed_text('english-partut-ud-2.0-170801.udpipe', file[0] + '.txt')
    d = find_possesive(parsed_text)
    print(count(d))
# Out:
# 20
# 25
# 12
# 18
# 19
# 28
# 24
# 26
# 26
# 20
# 23
# 21
# 19
# 30
# 47
# 21
# 20
# 20
# 18
# 26
# 20
# 21
# 19
# 26
# 22
# 33
# 35
# 32
# 29
# 28
# 26
# 26
# 29
# 25
# 35
# 30
# 39
# 34
# 22
# 23
# 19
# 22
# 18
# 23
# 23
# 17
# 25
# 20
# 22
# 26
# 27
# 22
# 13
# 31
# 30
# 30
# 16
# 34
# 20
# 34
# 29
# 23
# 29
# 30
# 20
# 27
# 35
# 36
# 30
# 28
# 26
# 29
# 41
# 28
# 23
# 32
# 36
# 33
# 23
# 18
# 23
# 3
# 23
# 22
# 19
# 17
# 15
# 19
# 23
# 22
# 22
# 13
# 12
# 5
# 4
# 9

# %%
from kkk import count, find_prep, adj_noun, find_ger_inf, parts_noun, count_vp

# %%
for file in file_grade:
    parsed_text = get_parsed_text('english-partut-ud-2.0-170801.udpipe', file[0] + '.txt')
    print(count_vp(parsed_text))
# Out:
# 20
# 12
# 23
# 14
# 22
# 11
# 23
# 14
# 15
# 8
# 14
# 12
# 32
# 26
# 38
# 30
# 41
# 34
# 44
# 45
# 30
# 24
# 32
# 30
# 43
# 44
# 27
# 34
# 30
# 41
# 37
# 42
# 25
# 32
# 32
# 43
# 30
# 32
# 14
# 14
# 14
# 8
# 11
# 14
# 8
# 14
# 21
# 21
# 24
# 10
# 17
# 12
# 8
# 12
# 14
# 12
# 17
# 25
# 34
# 38
# 49
# 21
# 28
# 34
# 24
# 35
# 40
# 33
# 37
# 31
# 35
# 25
# 47
# 24
# 23
# 25
# 31
# 35
# 10
# 5
# 8
# 1
# 15
# 18
# 13
# 10
# 10
# 17
# 10
# 22
# 17
# 10
# 13
# 14
# 5
# 13
