# %%
def tower(athlets):
    """
    Вычисляет максимальную высоту башни атлетов

    :param athlets: список tuple'ов (<масса атлета>, <сила атлета>)
    :return: высота башни (int)

    >>> tower([(3, 4), (2, 2), (7, 6), (4, 5)])
    3
    """

    pass

# %%
tower([(3, 4), (2, 2), (7, 6), (4, 5)])
# Out:
# [{1, 2, 3}, {3, 4}]

# %%
def tower(athlets):
    length = len(athlets)
    sorted_athl_strength = sorted(athlets, key=lambda y:y[1], reverse=True)
    #print(sorted_athl_strength)
    max_strength_lower = max(athlets, key=lambda y:y[1])
    print(max_strength_lower)
    i = 0
    max_len = 0
    while i < length-1:
        sorted_athl_strength = sorted_athl_strength[1:]
        print(sorted_athl_strength)
        maximum = sorted_athl_strength[0]
        print(maximum)
        if maximum[0] < max_strength_lower:
            max_len = max_len+1
        i += 1
    return max_len

# %%
htower_len([(3, 4), (2, 2), (7, 6), (4, 5)])
# Out:
# [(7, 6), (4, 5), (3, 4), (2, 2)]
# [(2, 2), (3, 4), (4, 5), (7, 6)]
# maximum tower length : 4

# %%
def tower(athlets):
    if athlets == []:
        return 0
    else:
        length = len(athlets)
        sorted_athl_weight = sorted(athlets, key=lambda y:(y[0], y[1]), reverse=True)
        print(sorted_athl_weight)
        max_strength_lower = sorted_athl_weight[0]# взяли того, кто больше всего выдержит
        print(max_strength_lower)
        max_len = 1# одного то мы точно выберем
        sum_maximums = 0
        towers = []
        for x in sorted_athl_weight[1:]:
            if x[0] < max_strength_lower[1]:
                towers.append([max_strength_lower, x])
        print(towers)
        for tower in towers:
            print(tower)
            sum_maximums = 0
            while sum_maximums < max_strength_lower:
                sorted_athl_weight = sorted_athl_weight[1:]# отсекаем уже выбранного
        #    print(sorted_athl_weight)
        #    maximum = sorted_athl_weight[0]
        #    max_strength_lower = sorted_athl_weight[0][1]
        #    sum_maximums = sum_maximums + maximum[0]
        #    max_len = max_len+1
        #return max_len

# %%
tower([(3, 4), (2, 2), (7, 6), (4, 5), (7, 8)])
# Out:
# [(7, 8), (7, 6), (4, 5), (3, 4), (2, 2)]
# (7, 8)
# [[(7, 8), (7, 6)], [(7, 8), (4, 5)], [(7, 8), (3, 4)], [(7, 8), (2, 2)]]

# %%
def tower(athlets):
    if athlets == []:
        return 0
    else:
        length = len(athlets)
        sorted_athl_weight = sorted(athlets, key=lambda y:(y[0], y[1]), reverse=True)
        print(sorted_athl_weight)
        max_strength_lower = sorted_athl_weight[0][1]
        #max_strength_lower = max(athlets, key=lambda y:y[1])[1]
        print(max_strength_lower)
        #max_len = 0
        #sum_maximums = 0
        #while sum_maximums < max_strength_lower:
        #    sorted_athl_hight = sorted_athl_hight[1:]
            #print(sorted_athl_hight)
        #    maximum = sorted_athl_hight[0]
         #   max_strength_lower = sorted_athl_hight[0][1]
            #print(sum_maximums, ' vs ', max_strength_lower)
         #   sum_maximums = sum_maximums + maximum[0]
         #   max_len = max_len+1
        #return max_len
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-189-b5c907834b9b> in <module>()
# ----> 1 max_strength_lower = max([], key=lambda y:y[1])[1]
#
# ValueError: max() arg is an empty sequence

# %%
max_strength_lower
# Out:
# 3

# %%
def htower_len(ht_wt):
    ht_sorted = sorted(ht_wt,reverse=True)
    print(ht_sorted)
    wt_sorted = sorted(ht_wt,key=lambda ht_wt:ht_wt[1])
    print(wt_sorted)
    max_len = 0

    len1 = len(ht_sorted)
    i=0
    while i < (len1-1):
        print(ht_sorted[i+1][1], ' vs ', ht_sorted[0][1])
        if(ht_sorted[i+1][1] < ht_sorted[0][1]):
            max_len = max_len+1
        i=i+1           

    print ("maximum tower length :" ,max_len)

# %%
htower_len([(90, 93), (58, 70), (63, 87), (25, 29), (69, 89), (18, 23), (39, 54)])
# Out:
# [(90, 93), (69, 89), (63, 87), (58, 70), (39, 54), (25, 29), (18, 23)]
# [(18, 23), (25, 29), (39, 54), (58, 70), (63, 87), (69, 89), (90, 93)]
# 89  vs  93
# 87  vs  93
# 70  vs  93
# 54  vs  93
# 29  vs  93
# 23  vs  93
# maximum tower length : 6

# %%
def htower_len(ht_wt):
    ht_sorted = sorted(ht_wt,reverse=True)
    wt_sorted = sorted(ht_wt,key=lambda ht_wt:ht_wt[1])
    max_len = 0
    print(ht_sorted)
    print(wt_sorted)
    len1 = len(ht_sorted)
    i=0
    while i < (len1-1):
        print(ht_sorted[i+1][1], '<', ht_sorted[0][1])
        if(ht_sorted[i+1][1] < ht_sorted[0][1]):
            max_len = max_len+1
        i=i+1           

    print ("maximum tower length :" ,max_len)
htower_len([(3, 7), (2, 2), (7, 6), (4, 5)])
# Out:
# [(7, 6), (4, 5), (3, 7), (2, 2)]
# [(2, 2), (4, 5), (7, 6), (3, 7)]
# 5 < 6
# 7 < 6
# 2 < 6
# maximum tower length : 2

# %%
def determine_largest_tower(beginning_index, a, beginning_tuple, solution_a):
    # base case
    if beginning_index >= len(a):
        return 0
    if solution_a[beginning_index] != -1:   # already computed
        return solution_a[beginning_index]

    # recursive case
    max_len = 0
    for i in range(beginning_index, len(a)):
        # if we can grab that value, check what the max would be
        if a[i][0] >= beginning_tuple[0] and a[i][1] >= beginning_tuple[1]:
            max_len = max(1 + determine_largest_tower(i+1, a, a[i], solution_a), max_len)
    solution_a[beginning_index] = max_len
    return max_len

def algorithm_for_human_towering(input_array):
    a = sorted(input_array)
    return determine_largest_tower(0, a, (-1,-1), [-1] * len(a))

a = [(90, 93), (58, 70), (63, 87), (25, 29), (69, 89), (18, 23), (39, 54)]
print (algorithm_for_human_towering(a))
# Out:
# 7

# %%
def determine_largest_tower(beginning_index, a, beginning_tuple, solution_a):
    # base case
    if beginning_index >= len(a):
        return 0
    if solution_a[beginning_index] != -1:   # already computed
        return solution_a[beginning_index]

    # recursive case
    max_len = 0
    for i in range(beginning_index, len(a)):
        # if we can grab that value, check what the max would be
        if a[i][0] >= beginning_tuple[0] and a[i][1] >= beginning_tuple[1]:
            max_len = max(1 + determine_largest_tower(i+1, a, a[i], solution_a), max_len)
    solution_a[beginning_index] = max_len
    return max_len

def tower(input_array):
    a = sorted(input_array)
    return determine_largest_tower(0, a, (-1,-1), [-1] * len(a))

# %%
tower([(3, 4), (2, 2), (7, 6), (4, 5)])
# Out:
# 4

# %%
List<HtWt> F( HtWt[] in, int n){

   ArrayList<HtWt> out = new ArrayList<HtWt>(n);
   out[0].add(int[0]); 

   int maxl = 0, tj = 0;

   for(int j = 1; j < n; j++){

      // choose the longest among all available
      int jl = 0, ti = 0, tp = 0;

      for( i = 0; i < j; i++){

         // find the first greater element in out[i]
         int x = F(out[i], in[j]);

         // find an appropriate position in i to insert j
         if ( x != -1)  
         {
            // compare with the longest list found so far
            if( (out[i].size + 1) > jl ){
              jl = (out[i].size + 1);
              ti = i;
              tp = x;
          }// if             
      }// for i
     out[j] = out[i];
     out[j].add( tp, o[j]);

     if ( out[j].size > maxl){
       maxl = out[j].size
       tj = j;
     } // if
   } // for j

   return out[tj];
 }  // F

 running time: n + nlogn

 For example, (80, 10), (80, 80), (90, 10), (90, 20), (90, 30)
 j = 0, len = 1, out[0] = (80,10) 
 j = 1, len = 1, out[1] = (80,80)
 j = 2, len = 1 , out[2] = (90, 10)
 j = 3, len = 2, out[3] = (80,10)->(90,20)
 j = 4, len = 1, out[4] = (90, 30)

# %%
def circus_tower(data):
    tower_height = 0
    sorted = data.sort_by{|x| x.first}
    for i in (0..sorted.size)
        if (sorted[i].last > sorted[i+1].last)
            sorted[i], sorted[i+1] = sorted[i+1], sorted[i]
            tower_height += 1
        end
    end
end
# Out:
#   File "<ipython-input-285-2e2532d1b764>", line 3
#     sorted = data.sort_by{|x| x.first}
#                          ^
# SyntaxError: invalid syntax

# %%
def tower(weight_and_height):
     
    def canAppend(seq, t):
        if len(seq) == 0:
            return True
        weight, height = seq[-1]
        return weight <= t[0] and height <= t[1]
     
    def getBestTower(sorted_list, index, bestSeq):
        if index >= len(sorted_list):
            return bestSeq
         
        bestWith = None
        if canAppend(bestSeq, sorted_list[index]): 
            clone = list(bestSeq)
            clone.append(sorted_list[index])
            bestWith = getBestTower(sorted_list, index+1, clone)
         
        bestWithout = getBestTower(sorted_list, index+1, bestSeq)
         
        #print (bestWith, 'vs', bestWithout)
        p = jj(bestWith)
        #print(p)
        if bestWith is not None and len(bestWith) > len(bestWithout) and jj(bestWith) == True:
            return bestWith
        else:
            return bestWithout
     
    s_weight_and_height = sorted(weight_and_height)
     
    return len(getBestTower(s_weight_and_height, 0, []))

def jj(tower):
    reversed_tower = list(reversed(tower))
    #print(tower)
    k = 1
    p = True
    for every in reversed_tower:
        #print(reversed_tower[k:])
        print(every[1], ' vs ', sum(x[0] for x in reversed_tower[k:]), [x[0] for x in reversed_tower[k:]])
        if every[1] > sum(x[0] for x in reversed_tower[k:]):
            p = True
        else:
            p = False
            return p
        k += 1
    return p

# %%
tower([(3, 4), (2, 2), (7, 6), (4, 5)])
# Out:
# 6  vs  9 [4, 3, 2]
# 6  vs  9 [4, 3, 2]
# 6  vs  5 [3, 2]
# 4  vs  2 [2]
# 2  vs  0 []
# 6  vs  5 [3, 2]
# 4  vs  2 [2]
# 2  vs  0 []
# 5  vs  5 [3, 2]
# 6  vs  6 [4, 2]
# 6  vs  6 [4, 2]
# 6  vs  2 [2]
# 2  vs  0 []
# 6  vs  2 [2]
# 2  vs  0 []
# 5  vs  2 [2]
# 2  vs  0 []
# 6  vs  5 [3, 2]
# 4  vs  2 [2]
# 2  vs  0 []
# 6  vs  5 [3, 2]
# 4  vs  2 [2]
# 2  vs  0 []
# 6  vs  7 [4, 3]
# 6  vs  7 [4, 3]
# 6  vs  3 [3]
# 4  vs  0 []
# 6  vs  3 [3]
# 4  vs  0 []
# 5  vs  3 [3]
# 4  vs  0 []
# 6  vs  4 [4]
# 5  vs  0 []
# 6  vs  4 [4]
# 5  vs  0 []
# 6  vs  0 []
# 6  vs  0 []
# 6  vs  4 [4]
# 5  vs  0 []
# 6  vs  4 [4]
# 5  vs  0 []
# 6  vs  3 [3]
# 4  vs  0 []
# 6  vs  5 [3, 2]
# 4  vs  2 [2]
# 2  vs  0 []
# 6  vs  5 [3, 2]
# 4  vs  2 [2]
# 2  vs  0 []
# 3

# %%
def getBestTower(sorted_list, index, bestSeq):
        if index >= len(sorted_list):
            return bestSeq
         
        bestWith = None
        if canAppend(bestSeq, sorted_list[index]): 
            clone = list(bestSeq)
            clone.append(sorted_list[index])
            bestWith = getBestTower(sorted_list, index+1, clone)
         
        bestWithout = getBestTower(sorted_list, index+1, bestSeq)
         
        #print(bestWith, bestWithout)
        if bestWith is not None and len(bestWith) > len(bestWithout) and jj(bestWith) == True:
            return bestWith
        else:
            return bestWithout

def canAppend(seq, t):
    print(seq)
    if len(seq) == 0:
        return True
    weight, height = seq[-1]
    #print(weight <= t[0])
    return weight <= t[0] and height <= t[1]

def check(tower):
    reversed_tower = list(reversed(tower))
    #print(tower)
    k = 1
    p = True
    for every in reversed_tower:
        #print(reversed_tower[k:])
        #print(every[1], ' vs ', sum(x[0] for x in reversed_tower[k:]), [x[0] for x in reversed_tower[k:]])
        if every[1] > sum(x[0] for x in reversed_tower[k:]):
            p = True
        else:
            p = False
            return p
        k += 1
    return p

def tower(athletes):
    athlets_sorted_weigth = sorted(athletes)
    result = len(getBestTower(athlets_sorted_weigth, 0, []))
    return result

def subseqs(seq, length):
    for i in range(len(seq) - length + 1):
        yield seq[i:i+length]

# %%
import itertools
def check(tower):
    reversed_tower = list(reversed(sorted(tower)))
    #print(tower)
    k = 1
    p = True
    for every in reversed_tower:
        #print(reversed_tower[k:])
        print(every[1], ' vs ', sum(x[0] for x in reversed_tower[k:]), [x[0] for x in reversed_tower[k:]])
        if every[1] > sum(x[0] for x in reversed_tower[k:]):
            p = True
        else:
            p = False
            break
            #p = False
            #return p
        k += 1
    return p

def get_towers(athltes):
    length_tower = len(athltes)
    while length_tower > 0:
        print(length_tower)
        f = itertools.combinations(athltes, length_tower)
        for every in f:
            print(every)
            ch = check(every)
            print(ch)
            if ch == False:
                continue
            else:
                return length_tower
            length_tower-=1

# %%
get_towers([(3, 4), (2, 2), (7, 6), (4, 5)])
# Out:
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# 6  vs  9 [4, 3, 2]
# False
# 4
# ((3, 4), (2, 2), (7, 6), (4, 5))
# ...

# %%
get_towers([(90, 93), (58, 70), (63, 87), (25, 29), (69, 89), (18, 23)])

# %%
result = []
start = 0
while start < len(lst):
    try:
        end = lst.index(item, start + 1)
    except ValueError:
        end = len(lst)
    result.extend(lst[x+start:x+start+size] for x in range(end - start - size + 1))
    start = end + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-474-1fc86029c4a1> in <module>()
#       3 while start < len(lst):
#       4     try:
# ----> 5         end = lst.index(item, start + 1)
#       6     except ValueError:
#       7         end = len(lst)
#
# NameError: name 'item' is not defined

# %%
lst = [1, 2, 3]

# %%
import itertools
k = itertools.combinations(lst, 2)

# %%
for kk in k:
    print(kk)
# Out:
# (1, 2)
# (1, 3)
# (2, 3)

# %%
def circusTower_optimized(weight_and_height):
     
    def canAppend(seq, t):
        if len(seq) == 0:
            return True
        weight, height = seq[-1]
        return weight <= t[0] and height <= t[1]
     
    # 해당 index로 끝나는 가장 긴 sequence를 찾는 함수입니다.
    def bestSequenceAtIndex(sorted_list, index, solutions):
        # index가 0이면 무조건 자기 자신만 존재하는 리스트를 리턴합니다.
        if index == 0:
            return [sorted_list[index]]
         
        # 현재까지의 solution들 중 append해서 가장 긴 sequence를 찾아 리턴합니다.
        best = [sorted_list[index]]
        for i in range(index):
            sol = solutions[i][:]
            if canAppend(sol, sorted_list[index]):
                sol.append(sorted_list[index])
                if len(sol) > len(best):
                    best = sol
        print(best)
        return best
     
    s_weight_and_height = sorted(weight_and_height)
     
    solutions = []
    best_sol_index = 0
    longest = 0
     
    # 결국 최종적으로는 solution들 중 가장 긴 것을 찾아 리턴합니다.
    for i in range(len(s_weight_and_height)):
        bestSeq = bestSequenceAtIndex(s_weight_and_height, i, solutions)
        solutions.append(bestSeq)
        if longest < len(bestSeq):
            longest = len(bestSeq)
            best_sol_index = i
     
    return solutions[i]

# %%
circusTower_optimized([(3, 4), (2, 2), (7, 6), (4, 5)])
# Out:
# [(2, 2), (3, 4)]
# [(2, 2), (3, 4), (4, 5)]
# [(2, 2), (3, 4), (4, 5), (7, 6)]
# [(2, 2), (3, 4), (4, 5), (7, 6)]

# %%
def subseqs(seq, length):
    for i in range(len(seq) - length + 1):
        yield seq[i:i+length]

# %%
list(subseqs(sorted([(3, 4), (2, 2), (7, 6), (4, 5)]), 3))
# Out:
# [[(2, 2), (3, 4), (4, 5)], [(3, 4), (4, 5), (7, 6)]]

# %%
# Python program to do inorder traversal without recursion
 
# A binary tree node
class Node:
     
    # Constructor to create a new node
    def __init__(self, data):
        self.data = data 
        self.left = None
        self.right = None
 
# Iterative function for inorder tree traversal
def inOrder(root):
     
    # Set current to root of binary tree
    current = root 
    s = [] # initialze stack
    done = 0
     
    while(not done):
         
        # Reach the left most Node of the current Node
        if current is not None:
             
            # Place pointer to a tree node on the stack 
            # before traversing the node's left subtree
            s.append(current)
         
            current = current.left 
 
         
        # BackTrack from the empty subtree and visit the Node
        # at the top of the stack; however, if the stack is 
        # empty you are done
        else:
            if(len(s) >0 ):
                current = s.pop()
                print current.data,
         
                # We have visited the node and its left 
                # subtree. Now, it's right subtree's turn
                current = current.right 
 
            else:
                done = 1
 
# Driver program to test above function
 
""" Constructed binary tree is
            1
          /   \
         2     3
       /  \
      4    5   """
 
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
 
inOrder(root)

# %%
from typing import Iterator


class Node(object):

    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


def traverse_inorder(node: Node) -> Iterator[Node]:
    lst = []
    now = node 
    stack = []
    it = True
    while it is True:
        if now is not None:
            stack.append(now)
            now = now.left 
        else:
            if stack != []:
                now = stack.pop()
                lst.append(now.value)
                now = now.right 
            else:
                it = False
    return lst
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

 
traverse_inorder(root)
# Out:
# [4, 2, 5, 1, 3]

# %%
1) Create an empty stack S.
2) Initialize current node as root
3) Push the current node to S and set current = current->left until current is NULL
4) If current is NULL and stack is not empty then 
     a) Pop the top item from stack.
     b) Print the popped item, set current = popped_item->right 
     c) Go to step 3.
5) If current is NULL and stack is empty then we are done.
# Out:
#   File "<ipython-input-554-3119a53a2534>", line 1
#     1) Create an empty stack S.
#      ^
# SyntaxError: invalid syntax

# %%
class Node(object):

    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

    def rotate_right(node: Node):
        n_r = node.left
        n_l = n_r.right
        r = node
        
        node = n_r
        r.left = n_l 
        n_r.right = node
    
    def rotate_left(node: Node):
        n_r = node.right
        n_l = n_r.left
        r = node
        
        node = n_r
        r.right = n_l
        n_r.left = r

# %%
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
print(root)
print(str(root))
# = rotate_right()
#a = a.addroot(9)
#print(a.key)

# %%
class node:
    def __init__(self):
        self.root = None
        self.size = 0
    def __len__(self):
        return self.size
  
class tree:
    def __init__(self, key = None, size = 0, left = None, right = None):
        self.key = key
        self.left = left
        self.right = right
        self.size = size
    def add(self, other):
        if self.key == None:
            self.key = other
            self.size = 1
            self.right = tree()
            self.left = tree()
        else:
            if other > self.key:
                return self.right.add(other)
            else:
                return self.left.add(other)
        self.size = self.len()
    def find(self, key):
        if self.key == None:
            return 0
        else:
            if key == self.key:
                return 1
            elif key > self.key:
                return self.right.find(key)
            else:
                return self.left.find(key)
    def getsize(self):
        if self.key == None:
            return 0
        return self.size
    def fixsize(self):
        self.size = self.left.getsize() + self.right.getsize() + 1
        return self.size
    def len(self):
        if self.key == None:
            return 0
        else:
            #self.size = self.left.len() + self.right.len() + 1
            return self.left.len() + self.right.len() + 1
    def rotateright(self): #правый поворот вокруг узла
        if self.left == None:
            return self
        s = self.size
        root = self.left
        self.left = root.right
        root.right = self
        root.size = s
        return root
    def rotateleft(self): #левый поворот вокруг узла
        if self.right == None:
            return self
        s = self.size
        root = self.right
        self.right = root.left
        root.left = self
        root.size = s
        return root
    
    def __str__(self):
        return str(self.)
    
    def addroot(self, key): #вставка нового узла с ключем key в корень
        if self.key == None:
            self.key = key
            self.size = 1
            self.right = tree()
            self.left = tree()
        elif self.key > key:
            self.left = self.left.addroot(key)
            s = self.rotateright()
            return s
        else:
            self.right = self.right.addroot(key)
            s = self.rotateleft()
            return s
  
a = tree()
a.add(5)
a.add(3)
a.add(8)
a.add(7)
a.add(10)
print(str(a))
a = a.rotateleft()
a = a.rotateleft()
a = a.addroot(9)
print(a.key)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-587-f7dd918b07d8> in <module>()
#      90 a.add(7)
#      91 a.add(10)
# ---> 92 print(str(a))
#      93 a = a.rotateleft()
#      94 a = a.rotateleft()
#
# <ipython-input-587-f7dd918b07d8> in __str__(self)
#      67
#      68     def __str__(self):
# ---> 69         return str(self.root)
#      70
#      71     def addroot(self, key): #вставка нового узла с ключем key в корень
#
# AttributeError: 'tree' object has no attribute 'root'

# %%
    def rotate_right(node):
        n_r = node.left
        n_l = n_r.right
        r = node
        
        node = n_r
        r.left = n_l 
        n_r.right = node
    
    def rotate_left(node):
        n_r = node.right
        n_l = n_r.left
        r = node
        
        node = n_r
        r.right = n_l
        n_r.left = r

# %%
class Node(object):

    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

    def traverse_inorder(node: Node) -> Iterator[Node]:
        lst = []
        now = node 
        stack = []
        it = True
        while it is True:
            if now is not None:
                stack.append(now)
                now = now.left 
            else:
                if stack != []:
                    now = stack.pop()
                    lst.append(now.value)
                    now = now.right 
                else:
                    it = False
        return lst

    def make_no_left_turn(root: Node) -> Node:
        if root is None:
            return
        else:
            make_no_left_turn(root.left)
            make_no_left_turn(root.right)
    
            if root.left == None:
                root.left = root.right
                root.right = None

            else:
                root.left.right = root.right
                root.right = None
            return 

root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
print(traverse_inorder(root))
print(make_no_left_turn(root))
# Out:
# [4, 2, 5, 1, 3]
# None

# %%
// Function to convert a normal binary tree to Left-child
// right-sibling (LC-RS) binary tree
void convert(Node *root)
{
    // base case: empty tree
	if (root == nullptr)
		return;

    // recursively convert left and right subtree first
	convert(root->left);
	convert(root->right);

	// if left child is empty, then make right child as left's
	// and set right to null
	if (root->left == nullptr)
	{
	   root->left = root->right;
	   root->right = nullptr;
	}

	// if left child already exists, then make right child of the
	// left child to point to right child of current node and
	// set current right child as null
	else
	{
		root->left->right = root->right;
		root->right = nullptr;
	}
}

# %%
class Node(object):

    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None
    
    def preorder(root):
        if root is None:
            return
        cout = root.value #cout << root->key << " ";
        preorder(root.left)
        preorder(root.right)
    
    def make_no_left_turn(root: Node) -> Node:
        if root is None:
            return
    
        make_no_left_turn(root.left)
        make_no_left_turn(root.right)
    
        if root.left is None:
            root.left = root.right
            root.right = None
        else:
            root.left.right = root.right
            root.right = None
        print (root.value)
    

root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

print(make_no_left_turn(root))
# Out:
# None

# %%
'''
   by Adrian Statescu <adrian@thinkphp.ro>
   Twitter: @thinkphp
   G+     : http://gplus.to/thinkphp
   MIT Style License
'''
'''
   Binary Search Tree
   ------------------
   Trees can come in many different shapes, and they can vary in the number of children allowed per node or in the way
   they organize data values within the nodes. One of the most commonly used trees in computer science is the binary tree.
   A binary tree is a tree in which each node can have at most two children. On child is identified as the left child and
   the other as the right child. The topmost node of the tree is known as the root node.It provides the single acccess point
   into the structure. The root node is the only node in the tree that does not have an incoming edge (an edge directed towart it)
   By definition every non=empty tree must have contain a root node.
  
'''

class Node:

      def __init__(self,info): #constructor of class

          self.info = info  #information for node
          self.left = None  #left leef
          self.right = None #right leef
          self.level = None #level none defined

      def __str__(self):

          return str(self.info) #return as string


class searchtree:

      def __init__(self): #constructor of class

          self.root = None


      def create(self,val):  #create binary search tree nodes

          if self.root == None:

             self.root = Node(val)

          else:

             current = self.root

             while 1:

                 if val < current.info:

                   if current.left:
                      current = current.left
                   else:
                      current.left = Node(val)
                      break;      

                 elif val > current.info:
                 
                    if current.right:
                       current = current.right
                    else:
                       current.right = Node(val)
                       break;      

                 else:
                    break 

      def bft(self): #Breadth-First Traversal

          self.root.level = 0 
          queue = [self.root]
          out = []
          current_level = self.root.level

          while len(queue) > 0:
                 
             current_node = queue.pop(0)
 
             if current_node.level > current_level:
                current_level += 1
                out.append("\n")

             out.append(str(current_node.info) + " ")

             if current_node.left:

                current_node.left.level = current_level + 1
                queue.append(current_node.left)
                  

             if current_node.right:

                current_node.right.level = current_level + 1
                queue.append(current_node.right)
                      
                 
          print ("".join(out)  ) 


      def inorder(self,node):
            
           if node is not None:
              
              self.inorder(node.left)
              print (node.info)
              self.inorder(node.right)


      def preorder(self,node):
            
           if node is not None:
              
              print (node.info)
              self.preorder(node.left)
              self.preorder(node.right)


      def postorder(self,node):
            
           if node is not None:
              
              self.postorder(node.left)
              self.postorder(node.right)
              print (node.info)

                        
tree = searchtree()     
arr = [8,3,1,6,4,7,10,14,13]
for i in arr:
    tree.create(i)
print ('Breadth-First Traversal')
tree.bft()
print ('Inorder Traversal')
tree.inorder(tree.root) 
print ('Preorder Traversal')
tree.preorder(tree.root) 
print ('Postorder Traversal')
tree.postorder(tree.root)
# Out:
# Breadth-First Traversal
# 8
# 3 10
# 1 6 14
# 4 7 13
# Inorder Traversal
# 1
# 3
# 4
# 6
# 7
# 8
# 10
# 13
# 14
# Preorder Traversal
# 8
# 3
# 1
# 6
# 4
# 7
# 10
# 14
# 13
# Postorder Traversal
# 1
# 4
# 7
# 6
# 3
# 13
# 14
# 10
# 8

# %%
# Элемент односвязного списка
class Node:
    def __init__(self, x, nxt=None):
        self.value = x
        self.next = nxt

    def __repr__(self):
        # Печатает связный список целиком
        return str(list(self))

    def __iter__(self):
        # Позволяет итерироваться по связному списку. Удобно для отладки.
        c = self
        while c:
            yield c.value
            c = c.next


def linked_list_partition(node: Node, pivot) -> Node:
    """
    >>> lst = Node(9, Node(8, Node(3, Node(1))))
    >>> linked_list_partition(lst, 5)
    [3, 1, 9, 8]
    """
    pass

# %%
class Node:
    def __init__(self, data, next=None):
        self.data = data
        self.next = next
        
def partition(node, val):
    b_n = node
    head = node
    right = False
    while node:
        #print(node.data)
        if node.data < val:
            if node == head:
                node = node.next
            else:
                head = Node(node.data, head)
                b_n.next = node.next
        else:
            right = True
            if right:
                r_e = node
        b_n = node
        node = node.next
        #print(head.data)
    r_e.next = None
    return head

# %%
lst = Node(9, Node(8, Node(3, Node(1))))
print(__repr__(partition(lst, 5)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-684-749d69cf1121> in <module>()
#       1 lst = Node(9, Node(8, Node(3, Node(1))))
# ----> 2 print(__repr__(partition(lst, 5)))
#
# NameError: name '__repr__' is not defined

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

    def __repr__(self):
        if self:
            return "{} -> {}".format(self.val, repr(self.next))

class Solution:
    # @param head, a ListNode
    # @param x, an integer
    # @return a ListNode
    def partition(self, head, x):
        dummySmaller, dummyGreater = ListNode(-1), ListNode(-1)
        smaller, greater = dummySmaller, dummyGreater

        while head:
            if head.val < x:
                smaller.next = head
                smaller = smaller.next
            else:
                greater.next = head
                greater = greater.next
            head = head.next

        smaller.next = dummyGreater.next
        greater.next = None

        return dummySmaller.next

if __name__ == "__main__":
    head = ListNode(1)
    head.next = ListNode(4)
    head.next.next = ListNode(3)
    head.next.next.next = ListNode(2)
    head.next.next.next.next = ListNode(5)
    head.next.next.next.next.next = ListNode(2)
    print (Solution().partition(head, ))
# Out:
# 1 -> 3 -> 2 -> 2 -> 4 -> 5 -> None

# %%
class ListNode(object):
    def __init__(self, x):
        self.val = x
        self.next = None

    def to_list(self):
        return [self.val] + self.next.to_list() if self.next else [self.val]


class Solution(object):
    def partition(self, head, x):
        """
        :type head: ListNode
        :type x: int
        :rtype: ListNode
        """
        dummy = ListNode(-1)
        dummy.next = head
        small_dummy = ListNode(-1)
        large_dummy = ListNode(-1)

        prev = dummy
        small_prev = small_dummy
        large_prev = large_dummy
        while prev.next:
            curr = prev.next
            if curr.val < x:
                small_prev.next = curr
                small_prev = small_prev.next
            else:
                large_prev.next = curr
                large_prev = large_prev.next
            prev = prev.next
        large_prev.next = None
        small_prev.next = large_dummy.next
        return small_dummy.next


if __name__ == "__main__":
    n1 = ListNode(9)
    n2 = ListNode(8)
    n3 = ListNode(3)
    n4 = ListNode(1)
    n5 = ListNode(5)
    n6 = ListNode(2)
    n1.next = n2
    n2.next = n3
    n3.next = n4
    r = Solution().partition(n1, 5)
    print(r.to_list())
# Out:
# [3, 1, 9, 8]

# %%
# Элемент односвязного списка
class Node:
    def __init__(self, x, nxt=None):
        self.value = x
        self.next = nxt

    def __repr__(self):
        # Печатает связный список целиком
        return str(list(self))

    def __iter__(self):
        # Позволяет итерироваться по связному списку. Удобно для отладки.
        c = self
        while c:
            yield c.value
            c = c.next

def linked_list_partition(node: Node, pivot) -> Node:
    """
    >>> lst = Node(9, Node(8, Node(3, Node(1))))
    >>> linked_list_partition(lst, 5)
    [3, 1, 9, 8]
    """
    el = Node(None)
    el.next = node
    small = small_el = Node(None) 
    large = large_el = Node(None) 
    while el.next:
        one = el.next
        if one.value < pivot:
            small_el.next = one
            small_el = small_el.next
        else:
            large_el.next = one
            large_el = large_el.next
        el = el.next
    large_el.next = None
    small_el.next = large.next
    return small.next.value

lst = Node(9, Node(8, Node(3, Node(1))))
assert linked_list_partition(lst, 5) == 3
lst = Node(49, Node(87, Node(69, Node(83, Node(0, Node(45, Node(87, Node(60, Node(97, Node(99, ))))))))))
assert linked_list_partition(lst, 70) == 49

# %%
lst = Node(9, Node(8, Node(3, Node(1))))
r = linked_list_partition(lst, 5)
print(r)
# Out:
# 3

# %%
lst = Node(49, Node(87, Node(69, Node(83, Node(0, Node(45, Node(87, Node(60, Node(97, Node(99, ))))))))))
r = linked_list_partition(lst, 70)
print(r)
# Out:
# 49

# %%
# Out:
#   File "<ipython-input-820-5eb7c3ba51f6>", line 1
#     49->69->0->45->60->87->83->87->97->99
#        ^
# SyntaxError: invalid syntax

# %%
class HashTable:
    def __init__(self):
        # создать массив на 1000 ячеек, в которых будет лежать None
        self.slots = [None] * 1000

    def add(self, element):
        # добавить элемент в хэш-таблицу, или бросить исключение если нет мест
        slot = hash(element) % 1000
        while self.slots[slot] is not None:
            slot = (slot + 1) % 1000
            raise Exception('Больше нет места в хэш-таблице!')
        if self.slots[slot] != element:
            self.slots[slot] = element
            

    def find(self, element):
        # вернуть True, если элемент есть в хэш-таблице, и False, если нет
        #print(self.slots[element] == None)
        slot = hash(element) % 1000
        if self.slots[slot] != None:
            return True
        else:
            return False

m = HashTable()
m.add("foo")
m.add(1)
m.add(23)
m.add(4)
assert m.find(1) == True
assert m.find(23) == True
assert m.find(4) == True
assert m.find(74) == False
assert m.find("foo") == True
assert m.find("test") == False
